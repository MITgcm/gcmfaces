% %%
%dirGcmfaces=[pwd filesep];
dirGcmfaces='./';
disp(['adding user-installed gcmfaces toolbox from: ' dirGcmfaces]);
p = genpath(dirGcmfaces); addpath(p);
% Out:
% adding user-installed gcmfaces toolbox from: ./

% %%
  disp(['loading user-installed octave packages: netcdf statistics']);
  pkg load netcdf;
  pkg load statistics;
% Out:
% loading user-installed octave packages: netcdf statistics

% %%
gcmfaces_global;
% Out:
% ...
%     gcmfaces_global at line 115 column 5

% %%
%dirGrid=[pwd filesep 'GRID' filesep];
dirGrid=['GRID' filesep];
disp(['loading user-installed grid from: ' dirGrid]);
grid_load(dirGrid,5,'compact');
% Out:
% loading user-installed grid from: GRID/

% %%
disp('illustrate gcmfaces format (using mygrid.Depth) and display mygrid contents (global structure)'); disp('');
gcmfaces_global; 
display(mygrid.Depth);
disp(fieldnames(mygrid));
% Out:
% illustrate gcmfaces format (using mygrid.Depth) and display mygrid contents (global structure)
%
%       nFaces: 5
%
%       f1: [90x270 double]
%       f2: [90x270 double]
%       f3: [90x90 double]
%       f4: [270x90 double]
%       f5: [270x90 double]
%
% {
%   [1,1] = dirGrid
%   [2,1] = nFaces
%   [3,1] = fileFormat
%   [4,1] = gcm2facesFast
%   [5,1] = memoryLimit
%   [6,1] = ioSize
%   [7,1] = facesSize
%   [8,1] = facesExpand
%   [9,1] = missVal
%   [10,1] = XC
%   [11,1] = XG
%   [12,1] = YC
%   [13,1] = YG
%   [14,1] = RAC
%   [15,1] = RAZ
%   [16,1] = DXC
%   [17,1] = DXG
%   [18,1] = DYC
%   [19,1] = DYG
%   [20,1] = hFacC
%   [21,1] = hFacS
%   [22,1] = hFacW
%   [23,1] = Depth
%   [24,1] = RC
%   [25,1] = RF
%   [26,1] = DRC
%   [27,1] = DRF
%   [28,1] = AngleCS
%   [29,1] = AngleSN
%   [30,1] = DXF
%   [31,1] = DYF
%   [32,1] = DXV
%   [33,1] = DYU
%   [34,1] = RAW
%   [35,1] = RAS
%   [36,1] = RAZfull
%   [37,1] = hFacCsurf
%   [38,1] = mskC
%   [39,1] = mskW
% ...

% %%
%plot -f png -w 600
gcmfaces_sphere(mygrid.Depth); 
title('plot generated using gcmfaces\_sphere(mygrid.Depth)')

% %%
disp('For extended tutorial uncomment the following line and follow instructions as prompted by gcmfaces_demo.m');
%gcmfaces_demo;
% Out:
% For extended tutorial uncomment the following line and follow instructions as prompted by gcmfaces_demo.m

% %%
warning('Some plotting functions fail when using octave + jupyter (e.g., try those below)');
%plot -f png -w 600
%imagesc(convert2array(mygrid.Depth)'); axis xy;
%qwckplot(mygrid.Depth)
